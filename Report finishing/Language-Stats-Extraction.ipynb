# %%
import matplotlib.pyplot as plt
from collections import Counter
from tqdm import tqdm
import seaborn as sns
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
# TW_LANG_PATH = 'bbcm-lang-analysis_tw-all-tweets-lang-annotations.csv' 
# FB_LANG_PATH = 'bbcm-lang-analysis_fb-all-posts-lang-annotations.csv'

# %%
# tw_lang_df = pd.read_csv(TW_LANG_PATH)
# fb_lang_df = pd.read_csv(FB_LANG_PATH)

# %%
COMBINED_LANG_PATH = 'bbcm-lang-analysis_combined-all-posts-lang-annotations-20201014.csv' 
comb_lang_df = pd.read_csv(COMBINED_LANG_PATH)
# Out:
# /Users/ay227/Desktop/first-trial/FT3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (1,2,6,8,10,13,14,16,17,18,21,22,24,25,28,31,34,36,39,40,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = comb_lang_df.rename({'combined/createdDate':'createdDate',
                          'combined/uniqueUserId':'uniqueUserId',
                         'combined/userHandle':'userHandle',
                         'combined/text':'text'}, axis=1)

df['createdDate'] = pd.to_datetime(df['createdDate'], errors='coerce')

# %%
df_year= df[df.createdDate.dt.year==2020]
df_month = df_year[df_year.createdDate.dt.month==9]
comb_lang_df = df_month

# %%
len(comb_lang_df)
# Out:
# 54328

# %% [markdown]
# # Language Propotions

# %%
# tw_lang_df = tw_lang_df[~tw_lang_df['language'].isna()]
# fb_lang_df = fb_lang_df[~fb_lang_df['language'].isna()]
comb_lang_df = comb_lang_df[~comb_lang_df['language'].isna()]

# %%
# Get all used lanaguage tags
# tw_langs = list(set(tw_lang_df['language'].fillna('EMPTY').values))
# fb_langs = list(set(comb_lang_df['language'].fillna('EMPTY').values))
comb_langs = list(set(comb_lang_df['language'].fillna('EMPTY').values))

# %%
# Languages across posts
def lang_from_posts(df, lang_col):
    return df.value_counts(lang_col).rename_axis(lang_col).reset_index(name='tweets-post_count')
# round(((tw_lang_df.value_counts('language')/len(tw_lang_df))*100),5) if we want percentage

# Num users using each language (at least once)
def get_users_using_lang(df, languages, lang_col, user_col):
    data = []

    for lang in languages:
        per_lang_df = df[df[lang_col] == lang].copy()
        per_lang_df = per_lang_df.drop_duplicates(user_col)
        total_num_users = len(df.drop_duplicates(user_col))
        data.append(dict(language=lang, used_by_percent=(round(len(per_lang_df)/total_num_users*100,3))))

    return pd.DataFrame(data).sort_values('used_by_percent', ascending=False)

# %%
comb_lang_per_posts = lang_from_posts(df=comb_lang_df, 
                    lang_col='language')
comb_lang_per_user = get_users_using_lang(df=comb_lang_df,
                     languages=comb_langs,
                    lang_col='language',
                    user_col='uniqueUserId')

combined_all_lang_propotion = comb_lang_per_posts.set_index('language').join(comb_lang_per_user.set_index('language'))
# the index here is the language
combined_all_lang_propotion.to_csv('lang_analysis-20201015/combined_all_lang_propotion.csv')

# %%
# tw_lang_per_posts = lang_from_posts(df=tw_lang_df, 
#                     lang_col='language')
# fb_lang_per_posts = lang_from_posts(df=fb_lang_df, 
#                     lang_col='language')

# %%
# tw_lang_per_user = get_users_using_lang(df=tw_lang_df,
#                      languages=tw_langs,
#                     lang_col='language',
#                     user_col='twitter.user/id')

# fb_lang_per_user = get_users_using_lang(df=fb_lang_df,
#                      languages=fb_langs,
#                     lang_col='language',
#                     user_col='crowdtangle.account/platformId')

# %%
# combined_tw_lang_propotion = tw_lang_per_posts.set_index('language').join(tw_lang_per_user.set_index('language'))
# combined_fb_lang_propotion = fb_lang_per_posts.set_index('language').join(fb_lang_per_user.set_index('language'))

# %%
# combined_tw_lang_propotion.to_csv('combined_tw_lang_propotion.csv')
# combined_fb_lang_propotion.to_csv('combined_fb_lang_propotion.csv')

# %% [markdown]
# # User Language   Propotion

# %%
def top_n_to_dict(most_common, prefix='top_lang'):
    
    data = {} 
    
    for i, (lang, count) in enumerate(most_common):
        data[f'{prefix}_{i+1}'] = lang
        data[f'{prefix}_count_{i+1}'] = count
        
    return data

# %%
def lang_user_propotion(df, user_col,lang_col,join_col):
        user_ids = list(set(df[user_col].values))

        u_data = []

        for u_id in tqdm(user_ids):
            u_df = df[df[user_col] == u_id].copy()

            lang_counts = Counter(u_df[lang_col].values).most_common(3)
            top_langs = top_n_to_dict(lang_counts)

            row_dict = {**dict(user_id=u_id), **top_langs}
            u_data.append(row_dict)

        _df = pd.DataFrame(u_data).sort_values('top_lang_count_1', ascending=False)
        _df = _df.set_index('user_id').join(df.set_index(user_col)[join_col], how='left')

        _df = _df.reset_index().drop_duplicates(subset=[join_col])
        _df = _df.rename(columns={'index': user_col})
        _df = _df[[
            join_col,
            user_col,
            'top_lang_1',
            'top_lang_count_1',
            'top_lang_2',
            'top_lang_count_2',
            'top_lang_3',
            'top_lang_count_3',
        ]]
        return _df

# %%
comb_lang_user_propotion = lang_user_propotion(df=comb_lang_df,
                            user_col='uniqueUserId',
                            lang_col='language',
                            join_col='userHandle')
comb_lang_user_propotion.to_csv('lang_analysis-20201015/comb_lang_user_propotion.csv',index=False)
# Out:
# 100%|██████████| 290/290 [00:01<00:00, 266.62it/s]

# %%
comb_lang_user_propotion
# Out:
#                                    userHandle            uniqueUserId  \
# 0                           fb-AmbassadeChine      fb-100399834672570
# 74                         fb-ChinaEmbHungary      fb-100796554693093
# 170                             fb-ChinainAus      fb-100850931425658
# 277                            fb-ChinaEmbSVK      fb-101287421460768
# 349             fb-Ambasada.Chinei.in.Moldova      fb-101387477954710
# 431                          fb-chinaembajada      fb-102057058042792
# 440               fb-konfuziusinstitutleipzig      fb-102186283183158
# 447                             fb-Chinaembbn      fb-102877517963784
# 565                        fb-EmbajadaChinaSV     fb-1030566077133287
# 600                             fb-chinaembua      fb-103492967817812
# 612                         fb-ChinaEmbAngola      fb-104069964576115
# 617                            fb-AmbChineCmr      fb-104092504428572
# 669     fb-crowdtangle.account/handle_missing     fb-1042824942404464
# 672                fb-AmbasadaChineiinRomania      fb-104493884371364
# 853                     fb-ChineseEmbassyinBB      fb-104495164280968
# 900                            fb-chinaemb.by      fb-104593117643539
# 903                          fb-ChinaEmbNepal      fb-104650787831634
# 909                     fb-ChineseEmbassyInNZ      fb-104806281106096
# 921                fb-chineseembassyinestonia      fb-105242924619771
# 923                              fb-chinaembd      fb-106507707486335
# 989                        fb-Chinese.Emb.Uga      fb-106608887435663
# 1046                       fb-chinaembassynmk      fb-106621514152583
# 1100                         fb-ChinaInNorway      fb-107064500777096
# 1134                        fb-ChinaEmbPoland      fb-108225127211908
# 1182                        fb-ChinainLebanon      fb-108776244023965
# 1210                         fb-ChineseEmbPNG      fb-108780127374577
# 1220              fb-chineseembassyinbulgaria      fb-108982464078168
# 1269                fb-EmbajadaChinaCostaRica      fb-109380197208723
# 1360                                fb-CCDEdu         fb-109440426760
# 1393               fb-ChineseEmbassyinGeorgia      fb-111412683679515
# 1395                       fb-kr.chinaembassy      fb-112831343478178
# 1440               fb-ChineseEmbassyInNigeria      fb-114211879961271
# 1501                            fb-LancsUniCI     fb-1151375868291878
# 1502              fb-bangorconfuciusinstitute     fb-1386697314896879
# 1505                               fb-SotonCI     fb-1455997148022534
# 1508            fb-KonfuziusInstitutFrankfurt      fb-154201734737067
# 1511             fb-ChineseEmbassyinIndonesia     fb-1575478812582390
# 1537                       fb-cissstrathclyde     fb-1589530071269631
# 1543                fb-ChineseEmbassyCambodia     fb-1635416159877318
# 1564                             fb-icmoldova     fb-1652353111490522
# 1568                fb-ConfuciusInstituteNJCU     fb-1674556129483687
# 1575                            fb-chinaembmy     fb-1729961127070014
# 1614                           fb-chinaemb.ss     fb-1732084740270235
# 1628            fb-confuciusinstituteaberdeen      fb-175677372857806
# 1631             fb-BrookesConfuciusInstitute     fb-1827076744287562
# 1634                    fb-ChinaConsulateCHGO     fb-1885797828331276
# 1651                    fb-paukphawfriendship      fb-191612647581463
# 1670    fb-KonfuziusInstitutNuernbergErlangen     fb-1916426428630816
# 1677                            fb-chinaembgm     fb-1934952550085647
# 1689                    fb-ChineseEmbassyinUS     fb-1956739414396955
# 1741                 fb-konfuziusinstitutBonn     fb-2103110919978365
# 1742                       fb-ambchineburkina     fb-2190905197854867
# 1772               fb-www.chinaembassy.org.zw      fb-232204800678880
# 1812                            fb-criarabic1      fb-232678173543084
# 2544       fb-UWPlattevilleConfuciusInstitute      fb-233312776705831
# 2546                           fb-Chinaemb.SG      fb-244605609584133
# 2576     fb-CentralConnecticutStateUniversity          fb-24834943605
# 2600       fb-ChineseEmbassyinAfghanistanDari      fb-265075717685746
# 2614                       fb-WMUInternationl      fb-308775102473864
# 2632                        fb-CIatGlasgowUni      fb-313062908803726
# 2636                              fb-websteru          fb-32419581551
# 2660                      fb-ChinaorgcnArabic      fb-333141140132864
# 2949                            fb-CIScotland      fb-334641089920780
# 2950                        fb-ChinaEUMission      fb-355117227946201
# 2972                                fb-QMULCI      fb-356361871458321
# 2980                           fb-SheffieldCI      fb-359522950794016
# 2986                          fb-ConfuciusMCR      fb-362336050448542
# 2991                        fb-CIUNCCharlotte      fb-365782880597740
# 2993                     fb-konfuziusinstitut      fb-369134663215311
# 2996                          fb-peoplearabic      fb-395997657147730
# 3210                             fb-chinainsa      fb-434624170049878
# 3234   fb-us.china.institute.bryantuniversity      fb-452906971513694
# 3236              fb-ConfuciusInstituteMunich      fb-454231044603061
# 3237                fb-hullconfuciusinstitute      fb-460521634072482
# 3240                fb-KonfuziusInstitutTrier      fb-469444060488542
# 3241                        fb-chinainstitute      fb-471000989752255
# 3272        fb-KonfuziusInstitutMetropoleRuhr      fb-537066246490900
# 3274             fb-AmbassadedeChineenTunisie      fb-548464552300660
# 3298                    fb-chineseconsulatesf      fb-559417600783428
# 3386                                      fb-      fb-641341015921819
# 3392                        fb-BEEmbassyChina      fb-652853511469685
# 3406                        fb-ChinaEmbTurkey      fb-654238228016230
# 3423                           fb-ubconfucius      fb-676311535835169
# 3426                 fb-chineseembassyiniraq1      fb-688845121577522
# 3462              fb-clevelandstateuniversity          fb-68928662834
# 3501                            fb-cgtnarabic      fb-691246177723161
# 4324                           fb-exploreutci      fb-758445954253182
# 4339                         fb-savannahstate          fb-81383047843
# 4365                     fb-bw.chineseembassy      fb-838988326148968
# 4424               fb-ChineseEmbassyinBangkok      fb-846555798724560
# 4436                     fb-UniversityofAkron          fb-87506681775
# 4462                    fb-ChineseConsulateLA      fb-899005777109124
# 4490               fb-ChineseEmbassyinNamibia      fb-910602595759270
# 4507                   fb-PresbyterianCollege           fb-9155137665
# 4536                    fb-ChinaEmbassyManila      fb-916398081890600
# 4659            fb-EmbassyofChinainTimorLeste      fb-954566381547297
# 4716                                 fb-BCIUL      fb-977421745655975
# 4720                       fb-chinaembassy.cz      fb-978664115512241
# 4776                          tw-PeopleArabic           tw-1005773462
# 4985                          tw-PuebloEnLnea           tw-1005789878
# 5285                         tw-Chine_au_Mali  tw-1027941926035701760
# 5293                            tw-oujianhong  tw-1033920834409312256
# 5296                       tw-ChineseZimbabwe  tw-1036897953334607873
# 5380                                tw-caixin            tw-104146203
# 5891                           tw-EmbZhangRun  tw-1077689818165972992
# 5957                       tw-EmbajadaChinaSV  tw-1097900802067304448
# 5995                          tw-XinhuaTravel  tw-1098870327017271296
# 6084                       tw-ConfuciusCovuni  tw-1108007465826897921
# 6120                       tw-ChineseEmbKenya  tw-1108351818680004608
# 6211                          tw-FlyOverChina  tw-1111926997813325824
# 6260                         tw-China_Amb_Zim  tw-1114497090426691586
# 6287                          tw-CGTNOfficial           tw-1115874631
# 9182                       tw-ChinaEmbajadaRD  tw-1121466332669775878
# 9196                         tw-ChinaembassyT  tw-1122771205545709569
# 9224                         tw-WangXianfeng8  tw-1123528448331456512
# 9523                        tw-ChineseEmbinUS  tw-1136383051917910017
# 9644                         tw-AmbCuiTiankai  tw-1136394437012152326
# 9651                       tw-AmbassadorZhang  tw-1140176664468418561
# 9702                           tw-PRCAmbNepal  tw-1140904762893688833
# 9710                        tw-ChineseSomalia  tw-1142709496042668032
# 9755                       tw-AmbChineBurundi  tw-1143603992146120705
# 9760                        tw-DrZhaoyongchen  tw-1152213233605992453
# 9875                        tw-AmbChenWeiQing  tw-1153720634372952064
# 9955                           tw-ChinaEmbKSA  tw-1153956415138095104
# 10024                       tw-ChinaEmbPoland  tw-1156569639914221568
# 10175                           tw-LiyingZHU1  tw-1158761872969084934
# 10180                           tw-thepapercn  tw-1160779539892408321
# 10709                       tw-AmbassadeChine  tw-1161600064214753280
# 11162                          tw-PDChinaLife  tw-1164937093656862720
# 11372                      tw-PDChinaBusiness  tw-1164939395939602432
# 11581                         tw-ChinaScience  tw-1164940374374330368
# 11792                           tw-AmbLiuQuan  tw-1168979212574892034
# 12558                            tw-li_xiaosi  tw-1169509456700465153
# 12689                      tw-ChineseEmbtoYEM  tw-1170953914331607040
# 12717                      tw-ChineseembassyJ  tw-1171292606803972097
# 12784                          tw-ChinaEmbEsp  tw-1171325918985510912
# 12875                         tw-china_emb_ng  tw-1171433208740601857
# 12962                         tw-Emb_ChinaVen  tw-1172502910917382145
# 13007                         tw-ChinaEmbinMR  tw-1173601346592919553
# 13008                        tw-chinaandsamoa  tw-1176446332875108352
# 13016                         tw-chine_guinee  tw-1176811042015502336
# 13030                           tw-Amb_Yiming  tw-1176961391133110272
# 13033                        tw-ambchinetchad  tw-1177222911918247938
# 13139                       tw-ChinaEmbKazakh  tw-1178542268262825985
# 13184                          tw-AmbChangHua  tw-1181459142894145541
# 13347                       tw-AmbLiuXiaoMing  tw-1181936905820266496
# 13579                            tw-MFA_China  tw-1183694592433983489
# 13958                      tw-SpokespersonCHN  tw-1183698123719200768
# 14231                      tw-ChinaMissionVie  tw-1184020957272399873
# 14267                       tw-Ambassador_Liu  tw-1186556215767252992
# 14328                       tw-ChineseEmbinHU  tw-1186904833661571072
# 14481                       tw-ChinaEmbAngola  tw-1187382248229789701
# 14497                        tw-CGZhangPingLA  tw-1192322561339641856
# 14508                       tw-ChineseEmbinUK  tw-1194927873171296257
# 14607                      tw-embassy_chinese  tw-1196213449539239936
# 14608                       tw-AmbLiaoLiqiang  tw-1201049689019310080
# 14676                      tw-ChinaAmbBelgium  tw-1201271102305165314
# 14711                      tw-EmbajadaChinaEc  tw-1201536069403058176
# 14835                       tw-ChineseLiberia  tw-1201828638171303936
# 14847                         tw-ChineseEmbTZ  tw-1204033086977200128
# 14872                       tw-ChinaCGCalgary  tw-1204200194390183936
# 14960                        tw-ChinaEmbajada  tw-1204496933886320641
# 14961                          tw-AmbChineCmr  tw-1206584459014918145
# 15037                        tw-ChinaEmbAddis  tw-1207558778842947584
# 15048                      tw-ChinaEmbGermany  tw-1207959651079393281
# 15173                           tw-Amb_ChenXu  tw-1212079621639794689
# 15206                        tw-AmbCHINEenRDC  tw-1215224180532109312
# 15292                            tw-ChinaIraq  tw-1216330086028316672
# 15320                          tw-China2ASEAN  tw-1219214266521096193
# 15525                       tw-ConsuladoCHNSC  tw-1219744155024445442
# 15540                           tw-ChinaCGMTL  tw-1220775270413717505
# 15551                      tw-chinaembaustria  tw-1222924488783945730
# 15648                           tw-chinacgedi  tw-1224988790302871552
# 15660                          tw-AmbZhouJian  tw-1225319823707602947
# 15868                       tw-ChinainLebanon  tw-1225742020301467649
# 16056                       tw-china_embajada  tw-1225886018869583874
# 16107                      tw-ChineseEmbinRus  tw-1226082749683032064
# 16134                          tw-ChinaEmbSVK  tw-1226820755721248769
# 16185                       tw-ChineseEmb_PNG  tw-1227394803911938048
# 16223                      tw-ChinaEmbIreland  tw-1229082104656470017
# 16235                         tw-ChinaEmbPeru  tw-1229881161171775488
# 16274                          tw-consulat_de  tw-1230410541547560960
# 16389                       tw-ChineseEmbinCZ  tw-1231881286693916675
# 16486                          tw-DrZhaoYanbo  tw-1233016806698373122
# 16612                           tw-ChinaAmbUN  tw-1233144962583343105
# 16730                      tw-GeneralkonsulDu  tw-1233405256048009217
# 16804                         tw-EmbChinaCuba  tw-1234962650053910528
# 16901                         tw-ChinaEmbinGH  tw-1235154463901585413
# 16914                           tw-China_Lyon  tw-1235580233669099522
# 16934                        tw-cidcaofficial  tw-1236602774474772481
# 16966                          tw-AmbFengBiao  tw-1239145878558068737
# 16967                          tw-ChinaEmbArg  tw-1239943788166070277
# 17031                         tw-ConsulateSan  tw-1239950242113413121
# 17114                            tw-AmbChenBo  tw-1239963267986001921
# 17124                      tw-AmbLiuGuangYuan  tw-1240198718143504385
# 17187                           tw-ChinaEmbSL  tw-1240860947826311169
# 17252                           tw-EmbChinaGE  tw-1242881237733314561
# 17291                      tw-SpokespersonHZM  tw-1245242068110213120
# 17303                            tw-YXiusheng  tw-1245496544557703173
# 17621                      tw-ChineAmbDjibout  tw-1250704920153554944
# 17708                       tw-ChinaConSydney  tw-1253534354032087041
# 18049                          tw-EmbChina_RS  tw-1257956722423091200
# 18061                        tw-Chinadaily_CH  tw-1267019174921908230
# 18380                            tw-PDChinaHK  tw-1270023039548362754
# 18450                             tw-FuCong17  tw-1273416484094525440
# 18469                            tw-criarabic           tw-1373495347
# 18924                               tw-zlj517            tw-141627220
# 19425                           tw-chinaorgcn            tw-147491390
# 20096                            tw-PDChinese           tw-1531801543
# 20883                              tw-CNS1952           tw-1597435105
# 22132                         tw-CGTNFrancais           tw-1667162474
# 22955                         tw-GoldsmithsCI           tw-1670671752
# 22964                       tw-ChinaEUMission           tw-1899984391
# 23085                        tw-shanghaidaily             tw-19140447
# 24742                       tw-LeedsConfucius           tw-2166586458
# 24791                        tw-ChnEmbassy_jp           tw-2459061450
# 24850                          tw-UKConfucius           tw-2520513692
# 24911                        tw-RenminDeutsch           tw-2523812532
# 25027                       tw-ChinaEmbOttawa           tw-2562545263
# 25115                        tw-Confucius_UoS           tw-2792664665
# 25143                       tw-ChinaDailyAsia            tw-280406148
# 25424                      tw-CISSStrathclyde           tw-2904895324
# 25472                            tw-CCTV_Plus           tw-2985114866
# 26287                               tw-CRIjpn           tw-3007739821
# 27056                            tw-XHMyanmar           tw-3033801332
# 27057                           tw-UCL_IOE_CI            tw-304314830
# 27060                        tw-peopledailyJP            tw-304506442
# 27326                           tw-XHJapanese           tw-3089531347
# 28060                         tw-ConfuciusMCR            tw-312054712
# 28078                      tw-Chinamission2un           tw-3210919822
# 28311                      tw-ChinaMissionGva           tw-3254484081
# 28551                        tw-XinhuaChinese           tw-3319804777
# 29412                        tw-ChinaPlusNews             tw-33400255
# 29827                            tw-XHSwahili           tw-3375411646
# 30295                           tw-Echinanews            tw-338736117
# 31344                          tw-CI4Scotland             tw-34959268
# 31356                            tw-chinascio           tw-3508175477
# 31568                        tw-french_renmin            tw-351403622
# 31853                          tw-XHportugues           tw-3576724694
# 32248                            tw-CathayPak           tw-3612384374
# 32325                            tw-XHdeutsch           tw-3740852061
# 32552                          tw-ShanghaiEye           tw-3910925474
# 33142                       tw-ChinaEmbTurkey           tw-4030814476
# 33153                          tw-WanmingYang           tw-4114061121
# 33239                             tw-yiwen_zh           tw-4236451217
# 33250                      tw-Chinacultureorg           tw-4331355020
# 33350                          tw-CriFrancais           tw-4780944534
# 33427                               tw-DMU_CI           tw-4782754515
# 33468                        tw-ConfuciusNJCU           tw-4830646103
# 33500                               tw-XHNews            tw-487118986
# 36100                            tw-SixthTone           tw-4891767710
# 36356                      tw-globaltimesnews             tw-49616273
# 39452                        tw-BeijingReview             tw-50910154
# 39884                      tw-ChinaInstitute_            tw-556215059
# 39952                                 tw-CCTV             tw-56644534
# 40306                      tw-Guangming_Daily            tw-599026769
# 40608                           tw-cgtnafrica            tw-619855057
# 41686                          tw-cgtnamerica            tw-620136960
# 42978                           tw-cctvarabic            tw-713808776
# 42992                           tw-yicaichina   tw-714684004495204352
# 44029                            tw-XHespanol            tw-722950850
# 44662                             tw-XHSports   tw-736101479715614720
# 44820                        tw-HullConfucius   tw-737921406042791936
# 44843                      tw-ConfuciusBangor   tw-760826219139072001
# 44857                        tw-cgtnenespanol   tw-761469053181370369
# 45762                           tw-Li_Baorong   tw-769011542033633280
# 46963                        tw-Confucius_HWU   tw-793107778701254656
# 46966                           tw-cgtnarabic   tw-805692634127736832
# 49373                       tw-XHNorthAmerica   tw-805780479496568832
# 49679                           tw-CGTNEurope   tw-814819352662790145
# 50125                        tw-ChinaEmbKabul   tw-826108735827345410
# 50145                       tw-ChinaConsulate   tw-826613505189085186
# 50165                      tw-confuciusedgehi   tw-829353238046588929
# 50168                       tw-Chinaembmanila   tw-833597469007097856
# 50305                       tw-ChinaInDenmark   tw-862289524679991298
# 50349                           tw-ChinaDaily             tw-87775422
# 52767                         tw-OBUConfucius   tw-882534687599624192
# 52782                            tw-weiasecas   tw-925561028469035008
# 53546                      tw-China_Amb_India   tw-938072041273430017
# 53685                      tw-ChinaEmSlovenia   tw-940862098216751105
# 53778                         tw-ConfuciusUNL   tw-950461134640963584
# 53779                       tw-ChineseEmb_Uga   tw-956892490510020608
# 53888                               tw-uofuci   tw-966127023318999041
# 53891                         tw-LiuHongyang4   tw-968392946901925888
# 53923                       tw-ChinaAmbUganda   tw-969850238365327360
# 53924                         tw-WSUConfucius            tw-979146277
# 53926                       tw-EmbaixadaChina   tw-992063308139319296
# 54199                              tw-AmbCina   tw-994453158301786113
#
#       top_lang_1  top_lang_count_1 top_lang_2  top_lang_count_2 top_lang_3  \
# 0             fr                70         en               3.0         sq
# 74            hu                83         en              12.0         es
# 170           en               106         ro               1.0        NaN
# 277           cs                68         en               3.0         he
# 349           ro                82        NaN               NaN        NaN
# 431           es                 9        NaN               NaN        NaN
# 440           de                 7        NaN               NaN        NaN
# 447           en               101         ro               7.0         fr
# 565           es                35        NaN               NaN        NaN
# 600           uk                12        NaN               NaN        NaN
# 612           pt                 3         ca               1.0         es
# 617           fr                48         en               4.0        NaN
# 669           ru                 3        NaN               NaN        NaN
# 672           en               141         ro              26.0         it
# 853           en                47        NaN               NaN        NaN
# 900        zh-cn                 3        NaN               NaN        NaN
# 903           en                 6        NaN               NaN        NaN
# 909           en                11         ro               1.0        NaN
# 921           en                 2        NaN               NaN        NaN
# 923           bn                49         en              17.0        NaN
# 989           en                50         ca               6.0         id
# 1046          en                49         mk               4.0         ro
# 1100          no                25         en               9.0        NaN
# 1134          pl                29         en              19.0        NaN
# 1182          en                16         ar              11.0         ro
# 1210          en                 9         ro               1.0        NaN
# 1220          bg                35         en               9.0      zh-cn
# 1269          es                91        NaN               NaN        NaN
# 1360          en                33        NaN               NaN        NaN
# 1393          en                 2        NaN               NaN        NaN
# 1395       zh-cn                23         ko              22.0        NaN
# 1440          en                60         ro               1.0        NaN
# 1501          en                 1        NaN               NaN        NaN
# 1502          en                 3        NaN               NaN        NaN
# 1505          en                 3        NaN               NaN        NaN
# 1508          de                 3        NaN               NaN        NaN
# 1511          id                21      zh-cn               3.0         en
# 1537          en                 6        NaN               NaN        NaN
# 1543       zh-cn                 9         en               9.0      zh-tw
# 1564          ro                 4        NaN               NaN        NaN
# 1568          en                 6         ro               1.0        NaN
# 1575          en                39        NaN               NaN        NaN
# 1614          en                14        NaN               NaN        NaN
# 1628          en                 3        NaN               NaN        NaN
# 1631          en                 3        NaN               NaN        NaN
# 1634          en                17        NaN               NaN        NaN
# 1651          ja                12         en               6.0      zh-cn
# 1670          de                 7        NaN               NaN        NaN
# 1677          en                12        NaN               NaN        NaN
# 1689          en                48         ro               3.0      zh-tw
# 1741          de                 1        NaN               NaN        NaN
# 1742          fr                30        NaN               NaN        NaN
# 1772          en                40        NaN               NaN        NaN
# 1812          ar               732        NaN               NaN        NaN
# 2544          en                 2        NaN               NaN        NaN
# 2546          en                29      zh-tw               1.0        NaN
# 2576          en                24        NaN               NaN        NaN
# 2600          fa                14        NaN               NaN        NaN
# 2614          en                18        NaN               NaN        NaN
# 2632          en                 3         tl               1.0        NaN
# 2636          en                24        NaN               NaN        NaN
# 2660          ar               289        NaN               NaN        NaN
# 2949          en                 1        NaN               NaN        NaN
# 2950          en                21      zh-cn               1.0        NaN
# 2972          en                 7      zh-cn               1.0        NaN
# 2980          en                 6        NaN               NaN        NaN
# 2986          en                 5        NaN               NaN        NaN
# 2991          en                 2        NaN               NaN        NaN
# 2993          en                 2         de               1.0        NaN
# 2996          ar               214        NaN               NaN        NaN
# 3210          en                23         id               1.0        NaN
# 3234          en                 2        NaN               NaN        NaN
# 3236          de                 1        NaN               NaN        NaN
# 3237          en                 3        NaN               NaN        NaN
# 3240          de                 1        NaN               NaN        NaN
# 3241          en                31        NaN               NaN        NaN
# 3272          de                 2        NaN               NaN        NaN
# 3274          ar                13         fr              11.0        NaN
# 3298          en                87         ro               1.0        NaN
# 3386          de                 6        NaN               NaN        NaN
# 3392          fr                 9         en               4.0         nl
# 3406          tr                17        NaN               NaN        NaN
# 3423          en                 3        NaN               NaN        NaN
# 3426          ar                34         fa               1.0         en
# 3462          en                38         de               1.0        NaN
# 3501          ar               823        NaN               NaN        NaN
# 4324          en                12        NaN               NaN        NaN
# 4339          en                24         da               1.0         es
# 4365          en                59        NaN               NaN        NaN
# 4424          th                 5         en               1.0        NaN
# 4436          en                26        NaN               NaN        NaN
# 4462          en                28        NaN               NaN        NaN
# 4490          en                17        NaN               NaN        NaN
# 4507          en                29        NaN               NaN        NaN
# 4536          en               120         tl               3.0        NaN
# 4659          en                54         ro               1.0         id
# 4716          en                 4        NaN               NaN        NaN
# 4720          cs                53         en               3.0        NaN
# 4776          ar               209        NaN               NaN        NaN
# 4985          es               294         it               2.0         de
# 5285          fr                 8        NaN               NaN        NaN
# 5293          es                 3        NaN               NaN        NaN
# 5296          en                84        NaN               NaN        NaN
# 5380          en               511        NaN               NaN        NaN
# 5891          es                51         en              11.0      zh-cn
# 5957          es                35         ca               1.0         hu
# 5995          en                85         tl               2.0         ro
# 6084          en                35         ro               1.0        NaN
# 6120          en                84         it               3.0         de
# 6211          en                49        NaN               NaN        NaN
# 6260          en                27        NaN               NaN        NaN
# 6287          en              2764         ca              28.0         it
# 9182          es                14        NaN               NaN        NaN
# 9196          en                17         sq               9.0         ro
# 9224          en               261      zh-cn               9.0         tl
# 9523          en               121        NaN               NaN        NaN
# 9644          en                 7        NaN               NaN        NaN
# 9651          en                51        NaN               NaN        NaN
# 9702          en                 7         hi               1.0        NaN
# 9710          en                44         it               1.0        NaN
# 9755          fr                 4         en               1.0        NaN
# 9760          en               108         tl               4.0      zh-tw
# 9875          ar                73         en               3.0         id
# 9955          ar                57         en              11.0      zh-cn
# 10024         en               114         pl              36.0         de
# 10175         fr                 5        NaN               NaN        NaN
# 10180         en               527      zh-cn               2.0        NaN
# 10709         fr               419         en              20.0         ro
# 11162         en               209         tl               1.0        NaN
# 11372         en               209        NaN               NaN        NaN
# 11581         en               211        NaN               NaN        NaN
# 11792         en               678      zh-cn              36.0         ro
# 12558         en               105         de              20.0      zh-cn
# 12689         ar                27         en               1.0        NaN
# 12717         ar                64         en               2.0         ca
# 12784         es                90         en               1.0        NaN
# 12875         en                85         ro               2.0        NaN
# 12962         es                38         en               6.0         ro
# 13007         ar                 1        NaN               NaN        NaN
# 13008         en                 8        NaN               NaN        NaN
# 13016         fr                12         tl               1.0         ca
# 13030         en                 3        NaN               NaN        NaN
# 13033         fr               106        NaN               NaN        NaN
# 13139         ru                41         uk               3.0         en
# 13184         en               129         fa              27.0         tl
# 13347         en               232        NaN               NaN        NaN
# 13579         en               324         fr              12.0         de
# 13958         en               271         ja               1.0         es
# 14231         en                36        NaN               NaN        NaN
# 14267         en                44         fr              12.0         cs
# 14328         hu               135         en              18.0        NaN
# 14481         pt                12         en               2.0         es
# 14497         en                11        NaN               NaN        NaN
# 14508         en                96      zh-cn               1.0         tl
# 14607         en                 1        NaN               NaN        NaN
# 14608         en                34         ar              33.0         da
# 14676         en                25         fr               9.0         it
# 14711         es               122         en               1.0         pt
# 14835         en                11      zh-cn               1.0        NaN
# 14847         en                25        NaN               NaN        NaN
# 14872         en                88        NaN               NaN        NaN
# 14960         es                 1        NaN               NaN        NaN
# 14961         fr                57         en              19.0        NaN
# 15037         en                11        NaN               NaN        NaN
# 15048         de                90         en              33.0      zh-tw
# 15173         en                33        NaN               NaN        NaN
# 15206         fr                79         en               7.0        NaN
# 15292         ar                23         en               5.0        NaN
# 15320         en               202      zh-tw               1.0         ca
# 15525         es                15        NaN               NaN        NaN
# 15540         en                 7         fr               3.0         ro
# 15551         en                72         de              24.0         he
# 15648         en                12        NaN               NaN        NaN
# 15660         en               196         ca               4.0         ro
# 15868         en               146         ar              39.0         de
# 16056         es                51        NaN               NaN        NaN
# 16107         ru                21         en               4.0         fr
# 16134         cs                33         en              17.0         he
# 16185         en                37         ro               1.0        NaN
# 16223         en                12        NaN               NaN        NaN
# 16235         es                39        NaN               NaN        NaN
# 16274         fr                77         en              36.0         tl
# 16389         cs                62         en              34.0         es
# 16486         en               124      zh-cn               1.0         ro
# 16612         en               116      zh-tw               2.0        NaN
# 16730         de                65         en               9.0        NaN
# 16804         es                93         ca               2.0         ro
# 16901         en                13        NaN               NaN        NaN
# 16914         fr                16         en               3.0         tl
# 16934         en                25         ar               3.0         fr
# 16966         ar                 1        NaN               NaN        NaN
# 16967         es                63         en               1.0        NaN
# 17031         en                82         de               1.0        NaN
# 17114         mk                10        NaN               NaN        NaN
# 17124         en                35         pl              28.0        NaN
# 17187         en                55      zh-cn               9.0         tl
# 17252         es                36      zh-tw               2.0         tl
# 17291         en                12        NaN               NaN        NaN
# 17303         en               294         tl              13.0         ro
# 17621         fr                75         en              10.0         ca
# 17708         en               339      zh-tw               1.0         tl
# 18049         mk                12        NaN               NaN        NaN
# 18061      zh-tw               316      zh-cn               3.0        NaN
# 18380      zh-tw                63         en               5.0      zh-cn
# 18450         en                19        NaN               NaN        NaN
# 18469         ar               452         fa               3.0        NaN
# 18924         en               490         fr               2.0         de
# 19425         en               670         tl               1.0        NaN
# 20096      zh-tw               783      zh-cn               4.0        NaN
# 20883      zh-tw              1238      zh-cn              11.0        NaN
# 22132         fr               820         en               2.0         it
# 22955         en                 9        NaN               NaN        NaN
# 22964         en               121        NaN               NaN        NaN
# 23085         en              1642         ca               8.0         ro
# 24742         en                49        NaN               NaN        NaN
# 24791         ja                53      zh-cn               2.0         en
# 24850         en                60         he               1.0        NaN
# 24911         de               116        NaN               NaN        NaN
# 25027         en                85         ro               2.0         tl
# 25115         en                26      zh-cn               1.0         ro
# 25143         en               277         tl               2.0         it
# 25424         en                47         de               1.0        NaN
# 25472         en               786         it              12.0         ca
# 26287         ja               769        NaN               NaN        NaN
# 27056         it                 1        NaN               NaN        NaN
# 27057         en                 3        NaN               NaN        NaN
# 27060         ja               266        NaN               NaN        NaN
# 27326         ja               717      zh-tw              14.0      zh-cn
# 28060         en                18        NaN               NaN        NaN
# 28078         en               231      zh-tw               1.0         fr
# 28311         en               239         ro               1.0        NaN
# 28551      zh-cn               671      zh-tw             186.0         ja
# 29412         en               404         ro               3.0         ca
# 29827         tl               254         id             210.0         hr
# 30295         en              1044         pt               1.0         de
# 31344         en                12        NaN               NaN        NaN
# 31356         en               209         ro               2.0         tl
# 31568         fr               280         tl               3.0         ro
# 31853         pt               357         es              27.0         it
# 32248         en                75         de               1.0         tl
# 32325         de               225         it               1.0         ro
# 32552         en               580         de               2.0         ko
# 33142         tr                11        NaN               NaN        NaN
# 33153         pt                56         es              17.0         en
# 33239         es                11        NaN               NaN        NaN
# 33250         en                95         fr               3.0         da
# 33350         fr                77        NaN               NaN        NaN
# 33427         en                40         ro               1.0        NaN
# 33468         en                32        NaN               NaN        NaN
# 33500         en              2531         ro              22.0         it
# 36100         en               256        NaN               NaN        NaN
# 36356         en              3000         ro              36.0         ca
# 39452         en               395         ro              14.0         ca
# 39884         en                67         fr               1.0        NaN
# 39952         en               351         ro               2.0         fr
# 40306         en               300         ro               1.0         tl
# 40608         en              1009         ca              22.0         fr
# 41686         en              1291         ro               1.0        NaN
# 42978         ar                14        NaN               NaN        NaN
# 42992         en              1008         ca              10.0         ro
# 44029         es               619         it               7.0         ca
# 44662         en               157         tl               1.0        NaN
# 44820         en                22         it               1.0        NaN
# 44843         en                12         ro               1.0         lt
# 44857         es               900         ca               3.0         ro
# 45762         es               866         en             251.0      zh-cn
# 46963         en                 3        NaN               NaN        NaN
# 46966         ar              2402         pl               1.0         sq
# 49373         en               296         ro               5.0         fr
# 49679         en               442         ro               3.0         tl
# 50125         en                20        NaN               NaN        NaN
# 50145         en                20        NaN               NaN        NaN
# 50165         en                 3        NaN               NaN        NaN
# 50168         en               136         ca               1.0        NaN
# 50305         en                44        NaN               NaN        NaN
# 50349         en              2405         tl               4.0         fr
# 52767         en                15        NaN               NaN        NaN
# 52782         es               574         en             107.0         ca
# 53546         en               138         fr               1.0        NaN
# 53685         en                88      zh-cn               2.0         de
# 53778         en                 1        NaN               NaN        NaN
# 53779         en                98         ca               9.0         tl
# 53888         en                 3        NaN               NaN        NaN
# 53891         en                27         tl               3.0      zh-cn
# 53923         en                 1        NaN               NaN        NaN
# 53924         en                 2        NaN               NaN        NaN
# 53926         pt               238         es              10.0         en
# 54199         it               118         en              10.0         es
#
#        top_lang_count_3
# 0                   1.0
# 74                  1.0
# 170                 NaN
# 277                 1.0
# 349                 NaN
# 431                 NaN
# 440                 NaN
# 447                 3.0
# 565                 NaN
# 600                 NaN
# 612                 1.0
# 617                 NaN
# 669                 NaN
# 672                 5.0
# 853                 NaN
# 900                 NaN
# 903                 NaN
# 909                 NaN
# 921                 NaN
# 923                 NaN
# 989                 1.0
# 1046                1.0
# 1100                NaN
# 1134                NaN
# 1182                1.0
# 1210                NaN
# 1220                4.0
# 1269                NaN
# 1360                NaN
# 1393                NaN
# 1395                NaN
# 1440                NaN
# 1501                NaN
# 1502                NaN
# 1505                NaN
# 1508                NaN
# 1511                2.0
# 1537                NaN
# 1543                2.0
# 1564                NaN
# 1568                NaN
# 1575                NaN
# 1614                NaN
# 1628                NaN
# 1631                NaN
# 1634                NaN
# 1651                1.0
# 1670                NaN
# 1677                NaN
# 1689                1.0
# 1741                NaN
# 1742                NaN
# 1772                NaN
# 1812                NaN
# 2544                NaN
# 2546                NaN
# 2576                NaN
# 2600                NaN
# 2614                NaN
# 2632                NaN
# 2636                NaN
# 2660                NaN
# 2949                NaN
# 2950                NaN
# 2972                NaN
# 2980                NaN
# 2986                NaN
# 2991                NaN
# 2993                NaN
# 2996                NaN
# 3210                NaN
# 3234                NaN
# 3236                NaN
# 3237                NaN
# 3240                NaN
# 3241                NaN
# 3272                NaN
# 3274                NaN
# 3298                NaN
# 3386                NaN
# 3392                1.0
# 3406                NaN
# 3423                NaN
# 3426                1.0
# 3462                NaN
# 3501                NaN
# 4324                NaN
# 4339                1.0
# 4365                NaN
# 4424                NaN
# 4436                NaN
# 4462                NaN
# 4490                NaN
# 4507                NaN
# 4536                NaN
# 4659                1.0
# 4716                NaN
# 4720                NaN
# 4776                NaN
# 4985                2.0
# 5285                NaN
# 5293                NaN
# 5296                NaN
# 5380                NaN
# 5891                1.0
# 5957                1.0
# 5995                1.0
# 6084                NaN
# 6120                2.0
# 6211                NaN
# 6260                NaN
# 6287               24.0
# 9182                NaN
# 9196                1.0
# 9224                8.0
# 9523                NaN
# 9644                NaN
# 9651                NaN
# 9702                NaN
# 9710                NaN
# 9755                NaN
# 9760                1.0
# 9875                2.0
# 9955                1.0
# 10024               1.0
# 10175               NaN
# 10180               NaN
# 10709               5.0
# 11162               NaN
# 11372               NaN
# 11581               NaN
# 11792              15.0
# 12558               3.0
# 12689               NaN
# 12717               1.0
# 12784               NaN
# 12875               NaN
# 12962               1.0
# 13007               NaN
# 13008               NaN
# 13016               1.0
# 13030               NaN
# 13033               NaN
# 13139               1.0
# 13184               3.0
# 13347               NaN
# 13579              10.0
# 13958               1.0
# 14231               NaN
# 14267               1.0
# 14328               NaN
# 14481               1.0
# 14497               NaN
# 14508               1.0
# 14607               NaN
# 14608               1.0
# 14676               1.0
# 14711               1.0
# 14835               NaN
# 14847               NaN
# 14872               NaN
# 14960               NaN
# 14961               NaN
# 15037               NaN
# 15048               1.0
# 15173               NaN
# 15206               NaN
# 15292               NaN
# 15320               1.0
# 15525               NaN
# 15540               1.0
# 15551               1.0
# 15648               NaN
# 15660               2.0
# 15868               1.0
# 16056               NaN
# 16107               1.0
# 16134               1.0
# 16185               NaN
# 16223               NaN
# 16235               NaN
# 16274               1.0
# 16389               1.0
# 16486               1.0
# 16612               NaN
# 16730               NaN
# 16804               1.0
# 16901               NaN
# 16914               1.0
# 16934               3.0
# 16966               NaN
# 16967               NaN
# 17031               NaN
# 17114               NaN
# 17124               NaN
# 17187               1.0
# 17252               1.0
# 17291               NaN
# 17303               4.0
# 17621               1.0
# 17708               1.0
# 18049               NaN
# 18061               NaN
# 18380               1.0
# 18450               NaN
# 18469               NaN
# 18924               2.0
# 19425               NaN
# 20096               NaN
# 20883               NaN
# 22132               1.0
# 22955               NaN
# 22964               NaN
# 23085               3.0
# 24742               NaN
# 24791               2.0
# 24850               NaN
# 24911               NaN
# 25027               1.0
# 25115               1.0
# 25143               1.0
# 25424               NaN
# 25472               7.0
# 26287               NaN
# 27056               NaN
# 27057               NaN
# 27060               NaN
# 27326               3.0
# 28060               NaN
# 28078               1.0
# 28311               NaN
# 28551               2.0
# 29412               3.0
# 29827               3.0
# 30295               1.0
# 31344               NaN
# 31356               1.0
# 31568               2.0
# 31853               6.0
# 32248               1.0
# 32325               1.0
# 32552               2.0
# 33142               NaN
# 33153              12.0
# 33239               NaN
# 33250               1.0
# 33350               NaN
# 33427               NaN
# 33468               NaN
# 33500              15.0
# 36100               NaN
# 36356              18.0
# 39452               8.0
# 39884               NaN
# 39952               1.0
# 40306               1.0
# 40608              13.0
# 41686               NaN
# 42978               NaN
# 42992               9.0
# 44029               5.0
# 44662               NaN
# 44820               NaN
# 44843               1.0
# 44857               1.0
# 45762              43.0
# 46963               NaN
# 46966               1.0
# 49373               4.0
# 49679               1.0
# 50125               NaN
# 50145               NaN
# 50165               NaN
# 50168               NaN
# 50305               NaN
# 50349               3.0
# 52767               NaN
# 52782              24.0
# 53546               NaN
# 53685               2.0
# 53778               NaN
# 53779               1.0
# 53888               NaN
# 53891               1.0
# 53923               NaN
# 53924               NaN
# 53926               7.0
# 54199               1.0

# %%
# tw_lang_user_propotion = lang_user_propotion(df=tw_lang_df,
#                             user_col='twitter.user/id',
#                             lang_col='language',
#                             join_col='twitter.user/screenName')


# fb_lang_user_propotion = lang_user_propotion(df=fb_lang_df,
#                             user_col='crowdtangle.account/platformId',
#                             lang_col='language',
#                             join_col='crowdtangle.account/handle')

# %%
# tw_lang_user_propotion.to_csv('tw_lang_user_propotion.csv')
# fb_lang_user_propotion.to_csv('fb_lang_user_propotion.csv')

# %%
# user_ids = list(set(tw_lang_df['twitter.user/id'].values))

# u_data = []

# for u_id in tqdm(user_ids):
#     u_df = tw_lang_df[tw_lang_df['twitter.user/id'] == u_id].copy()
    
#     lang_counts = Counter(u_df['language'].values).most_common(3)
#     top_langs = top_n_to_dict(lang_counts)
    
#     row_dict = {**dict(user_id=u_id), **top_langs}
#     u_data.append(row_dict)

# _df = pd.DataFrame(u_data).sort_values('top_lang_count_1', ascending=False)
# _df = _df.set_index('user_id').join(tw_lang_df.set_index('twitter.user/id')['twitter.user/screenName'], how='left')

# %%
# _df = _df.reset_index().drop_duplicates(subset=['twitter.user/screenName'])
# _df = _df.rename(columns={'index': 'twitter.user/id'})
# _df = _df[[
#     'twitter.user/screenName',
#     'twitter.user/id',
#     'top_lang_1',
#     'top_lang_count_1',
#     'top_lang_2',
#     'top_lang_count_2',
#     'top_lang_3',
#     'top_lang_count_3',
# ]]

# %%
_df

# %%
sns.set(font_scale=1.5)

tw_lang_df.value_counts('language').plot(kind='bar', figsize=(12, 6), rot=90)

plt.xlabel("Language", labelpad=14)
plt.ylabel("Post Languages", labelpad=14)
plt.title("Twitter Post Language", y=1.02)

# %%
sns.set(font_scale=1.5)

tw_lang_df[tw_lang_df['language'] != 'en'].value_counts('language').plot(kind='bar', figsize=(12, 6), rot=90)

plt.xlabel("Language", labelpad=14)
plt.ylabel("Post Languages", labelpad=14)
plt.title("Twitter Post Language (Without EN)", y=1.02)
